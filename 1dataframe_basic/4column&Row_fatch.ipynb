# %%
#column and row fatching
# COL - df[['col_name','col_name','col_name']]
# ROW 
    #iloc-searches using index position
    #loc- searches using index labels

# %%
import numpy as np
import pandas as pd
movies_df=pd.read_csv(r'C:\Users\HP\Desktop\all folder\pandas\movies.csv')
ipl_df=pd.read_csv(r'C:\Users\HP\Desktop\all folder\pandas\ipl-matches.csv')
student_details_dict={
    'name':['sanchit','ram','bipul','subh','shalini','anu'],
    'iq':[100,90,120,80,0,0],
    'marks':[80,70,100,50,0,0],
    'package':[10,7,14,2,0,0]
}
student_df=pd.DataFrame(student_details_dict)

# %%
#single columns -- it will be a series 
student_df['iq']
# Out:
# 0    100
# 1     90
# 2    120
# 3     80
# 4      0
# 5      0
# Name: iq, dtype: int64

# %%
#multiple columns
student_df[['iq','marks']]
# Out:
#     iq  marks
# 0  100     80
# 1   90     70
# 2  120    100
# 3   80     50
# 4    0      0
# 5    0      0

# %%
#1 col
movies_df['title_x']
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1624                   Tera Mera Saath Rahen
# 1625                    Yeh Zindagi Ka Safar
# 1626                         Sabse Bada Sukh
# 1627                                   Daaka
# 1628                                Humsafar
# Name: title_x, Length: 1629, dtype: object

# %%
#multi col
movies_df[['title_x','imdb_id','year_of_release']]
# Out:
#                                    title_x     imdb_id  year_of_release
# 0                 Uri: The Surgical Strike   tt8291224             2019
# 1                            Battalion 609   tt9472208             2019
# 2     The Accidental Prime Minister (film)   tt6986710             2019
# 3                          Why Cheat India   tt8108208             2019
# 4                          Evening Shadows   tt6028796             2018
# ...                                    ...         ...              ...
# 1624                 Tera Mera Saath Rahen   tt0301250             2001
# 1625                  Yeh Zindagi Ka Safar   tt0298607             2001
# 1626                       Sabse Bada Sukh   tt0069204             2018
# 1627                                 Daaka  tt10833860             2019
# 1628                              Humsafar   tt2403201             2011
#
# [1629 rows x 3 columns]

# %%
#rows

#iloc
student_df.iloc[1]
student_df.iloc[[1,0,2]]
student_df.iloc[2:]
# Out:
#       name   iq  marks  package
# 2    bipul  120    100       14
# 3     subh   80     50        2
# 4  shalini    0      0        0
# 5      anu    0      0        0

# %%
#how to set index in dataframe
student_df.set_index('name',inplace=True)
#also 0 1 2.. indexing is also present
student_df
# Out:
#           iq  marks  package
# name
# sanchit  100     80       10
# ram       90     70        7
# bipul    120    100       14
# subh      80     50        2
# shalini    0      0        0
# anu        0      0        0

# %%
student_df.loc['bipul']
# Out:
# iq         120
# marks      100
# package     14
# Name: bipul, dtype: int64

# %%
student_df.loc['bipul':'shalini']
#in index slicing 5:16 , 16 will not include but here label indexing include
# Out:
#           iq  marks  package
# name
# bipul    120    100       14
# subh      80     50        2
# shalini    0      0        0

# %%
#selcting both row and col -- yhis is also done by iloc
movies_df.iloc[0:3,0:3]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
movies_df.loc[0:2,'title_x':'imdb_id']
# Out:
#                                 title_x    imdb_id
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710

# %%
movies_df.head(1)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
#
#                                                story  \
# 0  Divided over five chapters  the film chronicle...
#
#                                              summary tagline  \
# 0  Indian army special forces execute a covert op...     NaN
#
#                                               actors wins_nominations  \
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...           4 wins
#
# ...

# %%
movies_df.set_index('original_title',inplace=True)

# %%
movies_df.head(2)
# Out:
#                                            title_x    imdb_id  \
# original_title
# Uri: The Surgical Strike  Uri: The Surgical Strike  tt8291224
# Battalion 609                        Battalion 609  tt9472208
#
#                                                                 poster_path  \
# original_title
# Uri: The Surgical Strike  https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                           NaN
#
#                                                                   wiki_link  \
# original_title
# Uri: The Surgical Strike  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# Battalion 609                   https://en.wikipedia.org/wiki/Battalion_609
#
#                                            title_y  is_adult  year_of_release  \
# original_title
# Uri: The Surgical Strike  Uri: The Surgical Strike         0             2019
# Battalion 609                        Battalion 609         0             2019
#
# ...
